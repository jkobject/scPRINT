# %%
import lamindb_setup as ln_setup
ln_setup.init(storage="./testdb", name="test", schema="bionty")
# Out:
# ✓ wrote new records from public sources.yaml to /Users/jkobject/.lamin/bionty/versions/sources_local.yaml!
#
# if you see this message repeatedly, run: import bionty; bionty.base.reset_sources()
# ✓ wrote new records from public sources.yaml to /Users/jkobject/.lamin/bionty/versions/sources_local.yaml!
#
# if you see this message repeatedly, run: import bionty; bionty.base.reset_sources()
# → connected lamindb: anonymous/test

# %%
import scanpy as sc
import numpy as np
import os
import urllib.request

from scprint.base import NAME
from scdataloader import Preprocessor
from scdataloader.utils import populate_my_ontology
from scprint.tasks import Denoiser
from scprint import scPrint
# %load_ext autoreload
# %autoreload 2
# Out:
# No module named 'triton'
# FlashAttention is not installed, not using it..
# ✓ wrote new records from public sources.yaml to /Users/jkobject/.lamin/bionty/versions/sources_local.yaml!
#
# if you see this message repeatedly, run: import bionty; bionty.base.reset_sources()
# ✓ wrote new records from public sources.yaml to /Users/jkobject/.lamin/bionty/versions/sources_local.yaml!
#
# if you see this message repeatedly, run: import bionty; bionty.base.reset_sources()
# → connected lamindb: anonymous/test
# /opt/homebrew/Caskroom/miniconda/base/envs/mtest5/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:15: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 12.0.1. Please consider upgrading.
#   warnings.warn(

# %%
populate_my_ontology(
        organisms=["NCBITaxon:10090", "NCBITaxon:9606"],
        sex=["PATO:0000384", "PATO:0000383"],
        # celltypes=None,
        # ethnicities=None,
        # assays=None,
        # tissues=None,
        # diseases=None,
        # dev_stages=None,
    )
# Out:
# ! CellType records from source (cl, 2024-02-13) are already in the database!
#    → pass `update=True` to update the records
# ! ambiguous validation in Bionty for 1 record: 'NCBITaxon:10090'
# ! Ethnicity records from source (hancestro, 3.0) are already in the database!
#    → pass `update=True` to update the records
# ! ExperimentalFactor records from source (efo, 3.63.0) are already in the database!
#    → pass `update=True` to update the records
# ! record with similar name exists! did you mean to load it?
#            uid                     name  ontology_id  abbr  \
# id
# 3150  63btPuBB  fever of unknown origin  EFO:0003952  None
#
#                                         synonyms  \
# id
# 3150  Unknown Origin Fever|Unknown Origin Fevers
#
#                                             description molecule instrument  \
# id
# 3150  Fever In Which The Etiology Cannot Be Ascertai...     None       None
#
#      measurement  source_id run_id  created_by_id  \
# id
# 3150        None         62   None              1
#
#                            updated_at
# id
# 3150 2024-09-04 14:21:12.085725+00:00
# ! Tissue records from source (uberon, 2024-02-20) are already in the database!
#    → pass `update=True` to update the records
# ! DevelopmentalStage records from source (hsapdv, 2020-03-10) are already in the database!
#    → pass `update=True` to update the records
# ! DevelopmentalStage records from source (mmusdv, 2020-03-10) are already in the database!
#    → pass `update=True` to update the records
# ! Disease records from source (mondo, 2024-02-06) are already in the database!
#    → pass `update=True` to update the records
# ! records with similar names exist! did you mean to load one of them?
#            uid                                               name  \
# id
# 839   7CKxLDlu                    obsolete congenital abnormality
# 881   5pHdg2Ic  obsolete myeloid and lymphoid neoplasms with e...
# 884   5lzQM8ub  myeloid and lymphoid neoplasms associated with...
# 1303  2f3luB0s                        abnormal pupillary function
# 1396  2slEWzUl                         abnormal threshold of rods
# 1565  6ZqhPFj2                    abnormal retinal correspondence
# 1770  3DvVEahq                      gastrin secretion abnormality
# 1962  6FITWYCe                  abnormality of glucagon secretion
# 6314  6NFTwVkD     normal breast-like subtype of breast carcinoma
# 7106  5nAdOPol       isolated anhidrosis with normal sweat glands
# 7168  3Oh1TC3K  Axenfeld-Rieger anomaly with partially absent ...
# 7234  boyQgFKV  calcific aortic disease with immunologic abnor...
# 7468  2ufJZwGL  dwarfism with stiff joints and ocular abnormal...
# 7969  1Ckl83dO  obsolete metachromatic leukodystrophy, adult-o...
# 8079  5X1tbYMG  obsolete abnormal neutrophil chemotactic response
# 8091  TNWQnFgm  noduli Cutanei, multiple, with urinary tract a...
# 8123  4yOtJm1j  optic atrophy 13 with retinal and foveal abnor...
# 8337  3zhNWHjz  pulmonic stenosis, atrial septal defect, and u...
# 8777  4cwPdoaU  anemia, nonspherocytic hemolytic, associated w...
# 8782  7WIoz0mt  anhidrosis, familial generalized, with abnorma...
#
#         ontology_id  abbr                                           synonyms  \
# id
# 839   MONDO:0000839  None  congenital anomaly or birth defect|congenital ...
# 881   MONDO:0000881  None                                               None
# 884   MONDO:0000884  None                                               None
# 1303  MONDO:0001303  None  abnormal pupillary function (disease)|abnormal...
# 1396  MONDO:0001396  None                     abnormal dark adaptation curve
# 1565  MONDO:0001565  None                                               None
# 1770  MONDO:0001770  None                                               None
# 1962  MONDO:0001962  None                     glucagon secretion abnormality
# 6314  MONDO:0006324  None  normal breast-like subtype of breast cancer|no...
# 7106  MONDO:0007118  None  Dann-Epstein-Sohar syndrome|anhidrosis caused ...
# 7168  MONDO:0007180  None  Axenfeld-Rieger anomaly with partially absent ...
# 7234  MONDO:0007246  None  calcific aortic disease with immunologic abnor...
# 7468  MONDO:0007480  None  dwarfism with stiff joints and ocular abnormal...
# 7969  MONDO:0007981  None  metachromatic leukodystrophy, adult-onset, wit...
# 8079  MONDO:0008091  None                                               None
# 8091  MONDO:0008103  None  noduli Cutanei, multiple, with urinary tract a...
# 8123  MONDO:0008135  None  optic atrophy 13 with retinal and foveal abnor...
# 8337  MONDO:0008349  None  pulmonic stenosis, atrial septal defect, and u...
# 8777  MONDO:0008789  None  anemia, nonspherocytic hemolytic, associated w...
# 8782  MONDO:0008794  None  anhidrosis, familial generalized, with abnorma...
#
#                                             description  source_id run_id  \
# id
# 23882                                               None         47   None
# 26179                                               None         47   None
#
#        created_by_id                       updated_at
# id
# 7705               1 2024-09-04 14:24:51.020246+00:00
# 16575              1 2024-09-04 14:24:52.165898+00:00
# 16688              1 2024-09-04 14:24:52.172428+00:00
# 19372              1 2024-09-04 14:24:52.454978+00:00
# 23882              1 2024-09-04 14:24:52.881080+00:00
# 26179              1 2024-09-04 14:24:53.124258+00:00

# %%
filepath = "./tests/test.h5ad"
ckpt_path = "./tests/small.ckpt"
if not os.path.exists(ckpt_path):
    url = "https://huggingface.co/jkobject/scPRINT/resolve/main/small.ckpt"
    urllib.request.urlretrieve(url, ckpt_path)

adata = sc.read_h5ad(filepath)
adata.obs.drop(columns="is_primary_data", inplace=True, errors="ignore")
adata.obs["organism_ontology_term_id"] = "NCBITaxon:9606"
preprocessor = Preprocessor(
    do_postp=False,
    force_preprocess=True,
)
adata = preprocessor(adata)
# Out:
# Dropping layers:  KeysView(Layers with keys: )
# checking raw counts
# removed 0 non primary cells, 1000 renamining
# filtered out 0 cells, 1000 renamining
# Removed 175 genes.
# validating
# /Users/jkobject/Documents/code/scdataloader/scdataloader/preprocess.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_utils.validate(adata, organism=adata.obs.organism_ontology_term_id[0])
# startin QC
# Seeing 161 outliers (16.10% of total dataset):
# done

# %%
model.use

# %%
import torch

# %%
model = scPrint.load_from_checkpoint(ckpt_path, precpt_gene_emb=None)
dn = Denoiser(
    plot_corr_size=10,
    batch_size=2,
    num_workers=1,
    max_len=300,
    downsample=0.3,
    predict_depth_mult=3,
    dtype=torch.float32,
)
metrics, random_indices, genes, expr_pred = dn(
    model=model,
    adata=adata,
)
# Out:
# you requested flash transformer but it requires the flash package which is not installed
# falling back to regular transformer...
# you requested flash transformer but it requires the flash package which is not installed
# falling back to regular transformer...
# you requested flash transformer but it requires the flash package which is not installed
# falling back to regular transformer...
# you requested flash transformer but it requires the flash package which is not installed
# falling back to regular transformer...
# RuntimeError caught: scPrint is not attached to a `Trainer`.
# 300
#   0%|          | 0/5 [00:00<?, ?it/s]
# ✓ wrote new records from public sources.yaml to /Users/jkobject/.lamin/bionty/versions/sources_local.yaml!
#
# if you see this message repeatedly, run: import bionty; bionty.base.reset_sources()
# ✓ wrote new records from public sources.yaml to /Users/jkobject/.lamin/bionty/versions/sources_local.yaml!
#
# if you see this message repeatedly, run: import bionty; bionty.base.reset_sources()
# → connected lamindb: anonymous/test
# 100%|██████████| 5/5 [00:11<00:00,  2.22s/it]

# %%
assert metrics["reco2full"] - metrics["noisy2full"] > 0

# %%
import shutil
import lamindb_setup as ln_setup

# %%
shutil.rmtree("./testdb")
ln_setup.delete("test", force=True)
# Out:
# ! calling anonymously, will miss private instances
