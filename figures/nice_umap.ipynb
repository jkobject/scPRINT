# %%
import scanpy as sc
from anndata.experimental import concat_on_disk
from umap import UMAP
import numpy as np

import bionty as bt
from scdataloader.utils import get_all_ancestors

import matplotlib
matplotlib.rcParams["figure.dpi"] = 72

import datamapplot

# %%
ls -alh ../data/step_0_predict.h5ad
# Out:
# -rw-r--r-- 1 jkalfon ml4ig 332M May 30 18:17 ../data/step_0_predict.h5ad

# %%
adata = sc.read_h5ad("../data/step_0_predict.h5ad")
adata

# %%
adata = sc.read_h5ad("../data/o2uniqsx_predict.h5ad")

# %%
celltype = bt.CellType.public(organism="all")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2560000 × 512
#     obs: 'pred_cell_type_ontology_term_id', 'pred_disease_ontology_term_id', 'pred_assay_ontology_term_id', 'pred_self_reported_ethnicity_ontology_term_id', 'pred_sex_ontology_term_id', 'pred_organism_ontology_term_id', 'conv_pred_cell_type_ontology_term_id', 'conv_pred_disease_ontology_term_id', 'conv_pred_assay_ontology_term_id', 'conv_pred_self_reported_ethnicity_ontology_term_id', 'sprint_leiden', 'louvain_1.0', 'louvain_0.5', 'louvain_0.2'
#     uns: 'louvain', 'neighbors', 'pred_assay_ontology_term_id_colors'
#     obsm: 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.embedding(adata, 'X_umap', color='pred_assay_ontology_term_id')
# Out:
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(adata, 'X_umap', color='louvain_0.5', legend_loc='on data')
# Out:
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(adata, 'X_umap', color='louvain_1.0', legend_loc='on data')
# Out:
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(adata, 'X_umap', color='louvain_1.0', legend_loc='on data')
# Out:
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obs['label'] = "Other"
adata.obs.loc[
    #(adata.obs['louvain_0.5']=='17') 
    #& 
    (adata.obs['conv_pred_cell_type_ontology_term_id']=='astrocyte of the cerebral cortex'), 'label'] = "THIS"
sc.pl.embedding(adata, 'X_umap', color='label')
# Out:
# ... storing 'label' as categorical
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
main = {"2": "oligodenderocytes",
"1": "disease associated t cells",
"0": "neurons and interneurons",
"3": "dementia associated neurons and interneurons",
"4": "cardiac tissue fibroblasts and endothelial cells",
"5": "neural cells (sci-RNAseq)",
"6": "fibroblasts",
"7": "disease associated monocytes",
"8": "normal t cells (10x v2)",
"9": "normal monocytes",
"10": "normal t cells (10x v3)",
"11": "disease associated B cells",
"12": "malignant cells and glioblastoma",
"13": "dementia associated oligodenderocytes",
"14": "epithelial cells (10x v3)",
"15": "cells of the trachea and lung",
"16": "glutamergic neurons (mouse)",
"17": "normal t cells (10x 5' v2)",
"18": "glutamergic neurons",
"19": "memory t cells (10x v2)",
"20": "monocytes",
"21": "normal B cells",
}

# %%
cat='0.5'

adata.obs[(adata.obs['louvain_'+cat].isin([str(i) for i in range(22)]))]['pred_organism_ontology_term_id'].value_counts().head(20)
# Out:
# pred_organism_ontology_term_id
# NCBITaxon:9606     1531783
# NCBITaxon:10090      49050
# Name: count, dtype: int64

# %%
num="14"
cat='0.5'
(
adata.obs[adata.obs['louvain_'+cat]==num]['pred_organism_ontology_term_id'].value_counts().head(3),
adata.obs[(adata.obs['louvain_'+cat]==num)]['conv_pred_cell_type_ontology_term_id'].value_counts().head(20), 
adata.obs[adata.obs['louvain_'+cat]==num]['conv_pred_disease_ontology_term_id'].value_counts().head(10),
adata.obs[adata.obs['louvain_'+cat]==num]['conv_pred_assay_ontology_term_id'].value_counts().head(10)
)
# Out:
# (pred_organism_ontology_term_id
#  NCBITaxon:9606     51531
#  NCBITaxon:10090        0
#  Name: count, dtype: int64,
#  conv_pred_cell_type_ontology_term_id
#  progenitor cell of mammary luminal epithelium                       16235
#  fibroblast of mammary gland                                         12600
#  pulmonary artery endothelial cell                                    6200
#  luminal epithelial cell of mammary gland                             4493
#  renal interstitial pericyte                                          4193
#  dermis microvascular lymphatic vessel endothelial cell               2480
#  myoepithelial cell of mammary gland                                  2137
#  mammary alveolar cell                                                1115
#  vasa recta descending limb cell                                       817
#  glomerular capillary endothelial cell                                 595
#  basal cell of epidermis                                                93
#  aortic smooth muscle cell                                              54
#  prostate gland microvascular endothelial cell                          49
#  epithelial cell of stratum germinativum of esophagus                   39
#  effector memory CD8-positive, alpha-beta T cell                        36
#  IgA plasma cell                                                        32
#  Sertoli cell                                                           24
#  basal epithelial cell of prostatic duct                                21
#  luminal cell of prostate epithelium                                    19
#  fibroblast of connective tissue of nonglandular part of prostate       17
#  Name: count, dtype: int64,
#  conv_pred_disease_ontology_term_id
#  normal                          51195
#  hydrosalpinx                      161
#  benign prostatic hyperplasia       66
#  lung adenocarcinoma                34
#  periodontitis                      31
#  COVID-19                           20
#  glioblastoma                        9
#  breast cancer                       7
#  pulmonary emphysema                 4
#  squamous cell lung carcinoma        3
#  Name: count, dtype: int64,
#  conv_pred_assay_ontology_term_id
#  10x 3' v3       51428
#  10x 5' v2          34
#  10x 3' v2          27
#  10x 5' v1          25
#  10x multiome       10
#  Seq-Well S3         6
#  Drop-seq            1
#  10x 3' v1           0
#  Seq-Well            0
#  sci-Plex            0
#  Name: count, dtype: int64)

# %%
adata.obs["merge_pred_cell_type_ontology_term_id"] = "None"
for k,v in main.items():
    loc = adata.obs['louvain_0.5']==k
    adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = v

# %%
main = {
    '0':"interneurons",
    '1':"disease associated T-cells",
    "2": 'sci-RNA-seq interneurons',
    "3": "monocytes",
    "4": "normal T-cells",
    "5": "epithelial cells", # mamary
    "6": "microglial cells", #only subpart "mature microglial cell"
   # "7": "oligodendrocytes",
    "8": "cultured and malignant cells",
    "9": "mouse pancreatic cells",
    "10": "colon and stomach cells",
#    "12": "cancer associated macrophages and T cells",
    "13": "B cells",
    "14": "Ig secreting cells and plasma cells",
    "15": "mouse neurons",
    #"16": 

}

# %%
adata.obs["merge_pred_cell_type_ontology_term_id"] = "None"
for k,v in main.items():
    loc = adata.obs['louvain_0.5']==k
    if k == "0":
        adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = v
        loc = loc & (adata.obs['conv_pred_disease_ontology_term_id']=='Lewy body dementia')
        adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = 'Lewy body dementia interneurons'
    elif k == "6":
        loc = loc & (adata.obs['conv_pred_cell_type_ontology_term_id']=='mature microglial cell')
        adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = v
    elif k == "9":
        loc = loc & (adata.obs['conv_pred_cell_type_ontology_term_id'].isin(["type B pancreatic cell","pancreatic A cell", "pancreatic stellate cell", 'pancreatic ductal cell']))
        adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = v
    else:
        adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = v
    
for k, v in {
    "4": "disease associated oligodendrocytes",
    "19": "oligodendrocytes",
    "46": "cancer associated regulatory T cells",
    "52": "syncytiotrophoblast cells",
    "36": "myocytes",
    "21": "cancer associated macrophages",
}.items():
    loc = adata.obs['louvain_1.0']==k
    adata.obs.loc[loc, 'merge_pred_cell_type_ontology_term_id'] = v

# %%
obj = bt.CellType.public(organism="all")
{i: obj.search(i, field=obj.ontology_id).name.iloc[0] for i in set(val)}

# %%
parentdf = (
    bt.CellType.filter()
    .df(include=["parents__ontology_id"])
    .set_index("ontology_id")[['parents__ontology_id']]
)
#parentdf.parents__ontology_id = parentdf.parents__ontology_id.astype(str)

# %%
anc={}
for i, (k, v) in enumerate(adata.obs['pred_cell_type_ontology_term_id'].value_counts().items()):
    if v > 100:
        anc[k] = get_all_ancestors(k, parentdf)

# %%
anc
# Out:
# {'CL:4023036': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000099',
#   'CL:0000151',
#   'CL:0000211',
#   'CL:0000255',
#   'CL:0000393',
#   'CL:0000402',
#   'CL:0000404',
#   'CL:0000498',
#   'CL:0000540',
#   'CL:0000548',
#   'CL:0000617',
#   'CL:0002319',
#   'CL:0002371',
#   'CL:0008031',
#   'CL:0010011',
#   'CL:0010012',
#   'CL:0011005',
#   'CL:2000029',
#   'CL:4023018',
#   'CL:4023083'},
#  'CL:4023050': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000104',
#   'CL:0000151',
#   'CL:0000211',
#   'CL:0000255',
#   'CL:0000393',
#   'CL:0000404',
#   'CL:0000540',
#   'CL:0000548',
#   'CL:0000598',
#   'CL:0000679',
#   'CL:0002319',
#   'CL:0002371',
#   'CL:0010012',
#   'CL:2000029',
#   'CL:2000049',
#   'CL:4023008',
#   'CL:4023040',
#   'CL:4023111'},
#  'CL:0002057': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000219',
#   'CL:0000226',
#   'CL:0000234',
#   'CL:0000255',
#   'CL:0000325',
#   'CL:0000473',
#   'CL:0000548',
#   'CL:0000576',
#   'CL:0000738',
#   'CL:0000763',
#   'CL:0000766',
#   'CL:0000842',
#   'CL:0000860',
#   'CL:0000988',
#   'CL:0001054',
#   'CL:0002242',
#   'CL:0002371',
#   'CL:0011026',
#   'CL:0011115'},
#  'CL:0002453': {'CL:0000000', 'CL:0000003', 'CL:0011026', 'CL:0011115'},
#  'CL:0000939': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000219',
#   'CL:0000226',
#   'CL:0000255',
#   'CL:0000542',
#   'CL:0000548',
#   'CL:0000623',
#   'CL:0000738',
#   'CL:0000824',
#   'CL:0000842',
#   'CL:0000988',
#   'CL:0001065',
#   'CL:0001067',
#   'CL:0002242',
#   'CL:0002371'},
#  'CL:4023121': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000099',
#   'CL:0000151',
#   'CL:0000211',
#   'CL:0000255',
#   'CL:0000393',
#   'CL:0000402',
#   'CL:0000404',
#   'CL:0000498',
#   'CL:0000540',
#   'CL:0000548',
#   'CL:0000617',
#   'CL:0002319',
#   'CL:0002371',
#   'CL:0008031',
#   'CL:0010011',
#   'CL:0010012',
#   'CL:0011005',
#   'CL:2000029',
#   'CL:4023017'},
#  'CL:0002629': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000095',
#   'CL:0000125',
#   'CL:0000129',
#   'CL:0000145',
#   'CL:0000219',
#   'CL:0000234',
#   'CL:0000235',
#   'CL:0000255',
#   'CL:0000325',
#   'CL:0000473',
#   'CL:0000548',
#   'CL:0000738',
#   'CL:0000763',
#   'CL:0000766',
#   'CL:0000864',
#   'CL:0000878',
#   'CL:0000988',
#   'CL:0002242',
#   'CL:0002319',
#   'CL:0002371'},
#  'CL:0000913': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000084',
#   'CL:0000219',
#   'CL:0000226',
#   'CL:0000255',
#   'CL:0000542',
#   'CL:0000548',
#   'CL:0000625',
#   'CL:0000738',
#   'CL:0000789',
#   'CL:0000791',
#   'CL:0000813',
#   'CL:0000842',
#   'CL:0000909',
#   'CL:0000988',
#   'CL:0001203',
#   'CL:0002242',
#   'CL:0002371',
#   'CL:0002419'},
#  'CL:0000128': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000095',
#   'CL:0000125',
#   'CL:0000126',
#   'CL:0000255',
#   'CL:0000548',
#   'CL:0002319',
#   'CL:0002371',
#   'CL:4023154'},
#  'CL:0000900': {'CL:0000000',
#   'CL:0000003',
#   'CL:0000084',
#   'CL:0000219',
#   'CL:0000226',
#   'CL:0000255',
#   'CL:0000542',
#   'CL:0000548',
#   'CL:0000625',
#   'CL:0000738',
#   'CL:0000789',
#   'CL:0000791',
#   'CL:0000842',
#   'CL:0000898',
#   'CL:0000988',
#   'CL:0002242',
#   'CL:0002371',
#   'CL:0002419'}}

# %%
lookup = celltype.lookup(celltype.ontology_id)

# %%
lookup.cl_0000939.parents
# Out:
# array(['CL:0000824'], dtype=object)

# %%
celltype.search(adata.obs['pred_cell_type_ontology_term_id'][0], field=celltype.ontology_id)
# Out:
# /local/scratch/tmp/ipykernel_3675028/2876346383.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   celltype.search(adata.obs['pred_cell_type_ontology_term_id'][0], field=celltype.ontology_id)
#                                                           name  \
# ontology_id
# CL:0000939   CD16-positive, CD56-dim natural killer cell, h...
# CL:0000930   CD4-negative, CD8-negative type I NK T cell se...
# CL:0002093                                secondary polar body
# CL:0000990                         conventional dendritic cell
# CL:0000991          CD11c-negative plasmacytoid dendritic cell
# ...                                                        ...
# CL:4023115                       type 1 spiral ganglion neuron
# CL:4023116                       type 2 spiral ganglion neuron
# CL:4023118   L5/6 non-Martinotti sst GABAergic cortical int...
# CL:4023120                          cochlea auditory hair cell
# CL:1001575                        uterine cervix squamous cell
#
#                                                     definition  \
# ontology_id
# CL:0000939   A Mature Natural Killer Cell That Has The Phen...
# CL:0000930   A Mature Nk T Cell That Secretes Interleukin-4...
# CL:0002093   A Small Cell Formed By The Second Meiotic Divi...
# CL:0000990   Conventional Dendritic Cell Is A Dendritic Cel...
# CL:0000991   Cd11C-Negative Plasmacytoid Dendritic Cell Is ...
# ...                                                        ...
# CL:4023115   A Spiral Ganglion Neuron That Innervates Inner...
# CL:4023116   A Spiral Ganglion Neuron That Innervates Outer...
# CL:4023118   A Sst Gabaergic Interneuron Does Not Have Mart...
# CL:4023120         An Auditory Hair Cell Found In The Cochlea.
# CL:1001575         Squamous Cell Of Uterine Cervix Epithelium.
#
#                                                       synonyms  \
# ontology_id
# CL:0000939   CD16-positive, CD56-positive natural killer ce...
# CL:0000930   CD4-negative, CD8-negative type I NK T cell se...
# CL:0002093             second polar body|polocytus secundarius
# CL:0000990          cDC|dendritic reticular cell|DC1|type 1 DC
# CL:0000991                       CD303-positive dendritic cell
# ...                                                        ...
# CL:4023115                         type I spiral ganglion cell
# CL:4023116                        type II spiral ganglion cell
# CL:4023118   L5/6 non-Martinotti morphology sst expressing ...
# CL:4023120                                  cochlear hair cell
# CL:1001575                                                None
#
#                               parents  __ratio__
# ontology_id
# CL:0000939               [CL:0000824]      100.0
# CL:0000930               [CL:0000924]       90.0
# CL:0002093               [CL:0002090]       90.0
# CL:0000990               [CL:0000451]       90.0
# CL:0000991               [CL:0000784]       90.0
# ...                               ...        ...
# CL:4023115               [CL:0011113]       50.0
# CL:4023116               [CL:0011113]       50.0
# CL:4023118               [CL:4023017]       50.0
# CL:4023120   [CL:0002374, CL:0000202]       50.0
# CL:1001575   [CL:0000076, CL:0002535]       50.0
#
# [2894 rows x 5 columns]

# %%
bt.CellType.search()
# Out:
# /local/scratch/tmp/ipykernel_3675028/4014102153.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bt.CellType.search(adata.obs['pred_cell_type_ontology_term_id'][0]).one()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bt.CellType.search(adata.obs['pred_cell_type_ontology_term_id'][0]).one()
#
# AttributeError: 'NoneType' object has no attribute 'one'

# %%
tokeep = [i for i,j in adata.obs['conv_pred_cell_type_ontology_term_id'].value_counts().items() if j > 10_000]

adata.obs["conv_pred_cell_type_ontology_term_id"] = adata.obs["conv_pred_cell_type_ontology_term_id"].cat.add_categories("None")


adata.obs.loc[~adata.obs['conv_pred_cell_type_ontology_term_id'].isin(tokeep), "conv_pred_cell_type_ontology_term_id"] = "None"

# %%
len(set(adata.obs['conv_pred_cell_type_ontology_term_id']))
# Out:
# 42

# %%
len(set(adata.obs['conv_pred_disease_ontology_term_id']))
# Out:
# 46

# %%
set(adata.obs['pred_sex_ontology_term_id'])
# Out:
# {'PATO:0000383', 'PATO:0000384'}

# %%
fig, ax =  datamapplot.create_plot(adata.obsm['X_umap'], np.array(adata.obs['conv_pred_disease_ontology_term_id'].tolist()), darkmode=False, title="Predicted Diseases", noise_label="normal")
fig.savefig("../pred_disease_sampled_1M_datamap.pdf", bbox_inches="tight")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/toolz/functoolz.py:457, in memoize.<locals>.memof(*args, **kwargs)
#     456 try:
# --> 457     return cache[k]
#     458 except TypeError:
#
# KeyError: (<datashader.glyphs.points.Point object at 0x7f1ad94afac0>, CPUDispatcher(<function LinearAxis.mapper at 0x7f1ad9ab3640>), CPUDispatcher(<function LinearAxis.mapper at 0x7f1ad9ab3640>), <function make_info.<locals>.info at 0x7f1ad93965f0>, CPUDispatcher(<function append at 0x7f1ad9396710>), False, None)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 fig, ax =  datamapplot.create_plot(adata.obsm['X_umap'], np.array(adata.obs['conv_pred_disease_ontology_term_id'].tolist()), darkmode=False, title="Predicted Diseases", noise_label="normal")
#       2 fig.savefig("../pred_disease_sampled_1M_datamap.pdf", bbox_inches="tight")
#       3 fig.show()
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datamapplot/create_plots.py:280, in create_plot(data_map_coords, labels, title, sub_title, noise_label, noise_color, color_label_text, color_label_arrows, label_wrap_width, label_color_map, figsize, dynamic_label_size, dpi, force_matplotlib, darkmode, highlight_labels, palette_hue_shift, palette_hue_radius_dependence, use_medoids, cmap, marker_color_array, **render_plot_kwds)
#     277 if "alpha" in render_plot_kwds:
#     278     alpha = render_plot_kwds.pop("alpha")
# --> 280 fig, ax = render_plot(
#     281     data_map_coords,
#     282     color_list,
#     283     label_text,
#     284     label_locations,
#     285     title=title,
#     286     sub_title=sub_title,
#     287     point_size=point_size,
#     288     alpha=alpha,
#     289     label_text_colors=None if not color_label_text else label_text_colors,
#     290     label_arrow_colors=None if not color_label_arrows else label_arrow_colors,
#     291     highlight_colors=[label_color_map[x] for x in unique_non_noise_labels],
#     292     figsize=figsize,
#     293     noise_color=noise_color,
#     294     label_size_adjustments=label_size_adjustments,
#     295     dpi=dpi,
#     296     force_matplotlib=force_matplotlib,
#     297     darkmode=darkmode,
#     298     highlight_labels=highlight_labels,
#     299     **render_plot_kwds,
#     300 )
#     302 return fig, ax
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datamapplot/plot_rendering.py:382, in render_plot(data_map_coords, color_list, label_text, label_locations, title, sub_title, figsize, fontfamily, label_linespacing, label_font_size, label_text_colors, label_arrow_colors, highlight_colors, point_size, alpha, dpi, label_base_radius, label_margin_factor, highlight_labels, highlight_label_keywords, add_glow, noise_color, label_size_adjustments, glow_keywords, darkmode, logo, logo_width, force_matplotlib, label_direction_bias, marker_type, marker_size_array, arrowprops, title_keywords, sub_title_keywords)
#     378     if marker_size_array is not None or marker_type != "o":
#     379         warn(
#     380             "Adjusting marker type or size cannot be done with datashader; use force_matplotlib=True"
#     381         )
# --> 382     datashader_scatterplot(
#     383         data_map_coords, color_list, point_size=point_size, ax=ax
#     384     )
#     386 # Create background glow
#     387 if add_glow:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datamapplot/plot_rendering.py:60, in datashader_scatterplot(data_map_coords, color_list, point_size, ax)
#      52 data = pd.DataFrame(
#      53     {
#      54         "x": data_map_coords.T[0],
#    (...)
#      57     }
#      58 )
#      59 color_key = {x: x for x in np.unique(color_list)}
# ---> 60 dsshow(
#      61     data,
#      62     ds.Point("x", "y"),
#      63     ds.count_cat("label"),
#      64     color_key=color_key,
#      65     norm="eq_hist",
#      66     ax=ax,
#      67     shade_hook=partial(tf.spread, px=point_size, how="over"),
#      68 )
#      69 return ax
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/mpl_ext.py:669, in dsshow(df, glyph, aggregator, agg_hook, shade_hook, plot_width, plot_height, x_range, y_range, width_scale, height_scale, norm, cmap, alpha, vmin, vmax, color_key, alpha_range, color_baseline, ax, fignum, aspect, **kwargs)
#     666     ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#     668 if isinstance(aggregator, reductions.by):
# --> 669     artist = CategoricalDSArtist(
#     670         ax,
#     671         df,
#     672         glyph,
#     673         aggregator,
#     674         agg_hook,
#     675         shade_hook,
#     676         plot_width=plot_width,
#     677         plot_height=plot_height,
#     678         x_range=x_range,
#     679         y_range=y_range,
#     680         width_scale=width_scale,
#     681         height_scale=height_scale,
#     682         color_key=color_key,
#     683         alpha_range=alpha_range,
#     684         color_baseline=color_baseline,
#     685         **kwargs
#     686     )
#     687 else:
#     688     if cmap is not None:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/mpl_ext.py:463, in CategoricalDSArtist.__init__(self, ax, df, glyph, aggregator, agg_hook, shade_hook, plot_width, plot_height, x_range, y_range, width_scale, height_scale, color_key, alpha_range, color_baseline, **kwargs)
#     460 self._color_baseline = color_baseline
#     462 # Aggregate the current view
# --> 463 binned = self.aggregate(self.axes.get_xlim(), self.axes.get_ylim())
#     464 if self.agg_hook is not None:
#     465     binned = self.agg_hook(binned)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/mpl_ext.py:237, in DSArtist.aggregate(self, x_range, y_range)
#     229     plot_height = self.plot_height
#     231 canvas = Canvas(
#     232     plot_width=plot_width,
#     233     plot_height=plot_height,
#     234     x_range=x_range,
#     235     y_range=y_range,
#     236 )
# --> 237 binned = bypixel(self.df, canvas, self.glyph, self.aggregator)
#     239 return binned
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/core.py:1335, in bypixel(source, canvas, glyph, agg, antialias)
#    1333 with warnings.catch_warnings():
#    1334     warnings.filterwarnings('ignore', r'All-NaN (slice|axis) encountered')
# -> 1335     return bypixel.pipeline(source, schema, canvas, glyph, agg, antialias=antialias)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/utils.py:114, in Dispatcher.__call__(self, head, *rest, **kwargs)
#     112 typ = type(head)
#     113 if typ in lk:
# --> 114     return lk[typ](head, *rest, **kwargs)
#     115 for cls in getmro(typ)[1:]:
#     116     if cls in lk:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/data_libraries/pandas.py:17, in pandas_pipeline(df, schema, canvas, glyph, summary, antialias)
#      15 @bypixel.pipeline.register(pd.DataFrame)
#      16 def pandas_pipeline(df, schema, canvas, glyph, summary, *, antialias=False):
# ---> 17     return glyph_dispatch(glyph, df, schema, canvas, summary, antialias=antialias)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/utils.py:117, in Dispatcher.__call__(self, head, *rest, **kwargs)
#     115 for cls in getmro(typ)[1:]:
#     116     if cls in lk:
# --> 117         return lk[cls](head, *rest, **kwargs)
#     118 raise TypeError("No dispatch for {0} type".format(typ))
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/data_libraries/pandas.py:32, in default(glyph, source, schema, canvas, summary, antialias, cuda)
#      30 x_mapper = canvas.x_axis.mapper
#      31 y_mapper = canvas.y_axis.mapper
# ---> 32 extend = glyph._build_extend(
#      33     x_mapper, y_mapper, info, append, antialias_stage_2, antialias_stage_2_funcs)
#      35 x_range = canvas.x_range or glyph.compute_x_bounds(source)
#      36 y_range = canvas.y_range or glyph.compute_y_bounds(source)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/toolz/functoolz.py:461, in memoize.<locals>.memof(*args, **kwargs)
#     459     raise TypeError("Arguments to memoized function must be hashable")
#     460 except KeyError:
# --> 461     cache[k] = result = func(*args, **kwargs)
#     462     return result
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/glyphs/points.py:216, in Point._build_extend(self, x_mapper, y_mapper, info, append, _antialias_stage_2, _antialias_stage_2_funcs)
#     210     for i in range(xs.shape[0]):
#     211         _perform_extend_points(i, sx, tx, sy, ty, xmin, xmax, ymin, ymax,
#     212                                xs, ys, xxmax, yymax, *aggs_and_cols)
#     214 @cuda.jit
#     215 @self.expand_aggs_and_cols(append)
# --> 216 def extend_cuda(sx, tx, sy, ty, xmin, xmax, ymin, ymax, xs, ys,
#     217                 xxmax, yymax, *aggs_and_cols):
#     218     i = cuda.grid(1)
#     219     if i < xs.shape[0]:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/macros.py:278, in expand_varargs.<locals>._expand_varargs(fn)
#     276 def _expand_varargs(fn):
#     277     fn_ast = function_to_ast(fn)
# --> 278     fn_expanded_ast = expand_function_ast_varargs(fn_ast, expand_number)
#     279     return function_ast_to_function(fn_expanded_ast, stacklevel=2)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/site-packages/datashader/macros.py:193, in expand_function_ast_varargs(fn_ast, expand_number)
#     190 assert isinstance(fn_ast, ast.Module)
#     192 # Copy ast so we don't modify the input
# --> 193 fn_ast = copy.deepcopy(fn_ast)
#     195 # Extract function definition
#     196 fndef_ast = fn_ast.body[0]
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
#     [... skipping similar frames: deepcopy at line 146 (1 times)]
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
#     [... skipping similar frames: deepcopy at line 146 (1 times)]
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
#     [... skipping similar frames: deepcopy at line 146 (112 times), _deepcopy_dict at line 231 (89 times), _reconstruct at line 271 (89 times), deepcopy at line 172 (89 times), _deepcopy_list at line 206 (22 times)]
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/miniconda3/envs/scprint17/lib/python3.10/copy.py:138, in deepcopy(x, memo, _nil)
#     135     memo = {}
#     137 d = id(x)
# --> 138 y = memo.get(d, _nil)
#     139 if y is not _nil:
#     140     return y
#
# KeyboardInterrupt:

# %%
adata.obs['conv_pred_cell_type_ontology_term_id'] = adata.obs['conv_pred_cell_type_ontology_term_id'].astype(str)

# %%
adata.obs['conv_pred_cell_type_ontology_term_id'].value_counts()
# Out:
# conv_pred_cell_type_ontology_term_id
# None                                                                   361938
# bronchus fibroblast of lung                                             84251
# kidney loop of Henle medullary thick ascending limb epithelial cell     69038
# chandelier pvalb GABAergic cortical interneuron                         47305
# malignant cell                                                          44958
# epithelial cell of proximal tubule segment 3                            38936
# vasa recta descending limb cell                                         34033
# parietal epithelial cell                                                30855
# glomerular capillary endothelial cell                                   30680
# kidney distal convoluted tubule epithelial cell                         29656
# CD14-positive, CD16-negative classical monocyte                         28855
# retinal rod cell                                                        28643
# alveolar macrophage                                                     24946
# kidney collecting duct principal cell                                   24431
# Sertoli cell                                                            23086
# kidney connecting tubule epithelial cell                                21850
# kidney loop of Henle thin ascending limb epithelial cell                21839
# enterocyte of colon                                                     21364
# L5 extratelencephalic projecting glutamatergic cortical neuron          21357
# oligodendrocyte                                                         19654
# type II pneumocyte                                                      17039
# double-positive, alpha-beta thymocyte                                   16073
# choroid plexus epithelial cell                                          15336
# Mueller cell                                                            15050
# DN3 thymocyte                                                           14838
# lung pericyte                                                           13218
# alveolar type 2 fibroblast cell                                         13138
# CD34-positive, CD38-negative hematopoietic stem cell                    12852
# hepatic stellate cell                                                   12043
# naive thymus-derived CD4-positive, alpha-beta T cell                    11935
# mesangial cell                                                          11794
# early lymphoid progenitor                                               11531
# fraction A pre-pro B cell                                               11529
# effector memory CD8-positive, alpha-beta T cell                         11334
# vascular leptomeningeal cell (Mmus)                                     11065
# mature microglial cell                                                  10883
# pancreatic D cell                                                       10854
# pancreatic ductal cell                                                  10554
# renal interstitial pericyte                                             10522
# CD1c-positive myeloid dendritic cell                                    10271
# dermis microvascular lymphatic vessel endothelial cell                  10243
# bronchial smooth muscle cell                                            10223
# Name: count, dtype: int64

# %%
sc.pl.umap(adata, color='merge_pred_cell_type_ontology_term_id')

# %%
sc.pl.umap(adata, color='merge_pred_cell_type_ontology_term_id', legend_loc='on data')
# Out:
# ... storing 'merge_pred_cell_type_ontology_term_id' as categorical
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /pasteur/appa/homes/jkalfon/miniconda3/envs/scprint17/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fig, ax =  datamapplot.create_plot(adata.obsm['X_umap'], np.array(adata.obs['merge_pred_cell_type_ontology_term_id'].tolist()), darkmode=False, title="Plot of scPRINT embeddings of cells across cellxgene", noise_label="None")
fig.savefig("../pred_celltype_sampled_1M_datamap.pdf", bbox_inches="tight")
fig.show()

# %%
fig, ax =  datamapplot.create_plot(adata.obsm['X_umap'], np.array(adata.obs['merge_pred_cell_type_ontology_term_id'].tolist()), darkmode=False, title="Plot of scPRINT embeddings of cells across cellxgene", noise_label="None")
fig.savefig("../pred_celltype_sampled_1M_datamap.pdf", bbox_inches="tight")
fig.show()
